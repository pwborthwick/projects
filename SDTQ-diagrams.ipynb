# %% [markdown]
# __coupled-cluster singles__
#
# |diagram    |    term          |    contractions         |  interpretation |
# |:----------|:---------------:|:----------------------:|:--------------:|
# |$S_1$    |  $$T_0(+1)$$ | $$0~~~~~0$$| $$f_{ai}$$ |
# |$S_{2a}$|$$T_2(-1)$$|$$+-~~~~~++--$$|$$t^{ac}_{ik}~f_{kc}$$|
# |$S_{2b}$|$$T_2(-1)$$|$$++-~~~~~++--$$|$$\frac{1}{2}~t^{cd}_{ik}~\langle ak \Vert cd \rangle$$|
# |$S_{2c}$|$$T_2(-1)$$|$$+--~~~~~++--$$|$$-\frac{1}{2}~t^{ac}_{kl}~\langle kl\Vert ic \rangle$$|
# |$S_{3a}$|$$T_1(0)$$|$$+~~~~~+-$$|$$t^{c}_{i}~f_{ac}$$|
# |$S_{3b}$|$$T_1(0)$$|$$-~~~~~+-$$|$$-t^{a}_{k}~f_{ki}$$|
# |$S_{3c}$|$$T_1(0)$$|$$+-~~~~~+-$$|$$t^{c}_{k}~\langle ak\Vert ic \rangle$$|
# |$S_{4a}$|$$T_1 T_2(-2)$$|$$+\vert+--~~~~~+-\vert++--$$|$$-\frac{1}{2}~t^c_i~t^{ad}_{kl}~\langle kl\Vert cd \rangle$$|
# |$S_{4b}$|$$T_1 T_2(-2)$$|$$-\vert++-~~~~~+-\vert++--$$|$$-\frac{1}{2}~t^a_k~t^{cd}_{il}~\langle kl\Vert cd \rangle$$|
# |$S_{4c}$|$$T_1 T_2(-2)$$|$$+-\vert+-~~~~~+-\vert++--$$|$$t^c_k~t^{da}_{li}~\langle kl\Vert cd \rangle$$|
# |$S_{5a}$|$$T_1^2(-1)$$|$$+\vert-~~~~~+-\vert+-$$|$$-t^c_i~t^a_k~f_{kc}$$|
# |$S_{5b}$|$$T_1^2(-1)$$|$$+\vert+-~~~~~+-\vert+-$$|$$t^c_i~t^d_k~\langle ak\Vert cd \rangle$$|
# |$S_{5c}$|$$T_1^2(-1)$$|$$-\vert+-~~~~~+-\vert+-$$|$$-t^a_k~t^c_l~\langle kl\Vert ic \rangle$$|
# |$S_6$|$$T_1^3(-2)$$|$$+\vert+-\vert-~~~~~+-\vert+-\vert+-$$|$$-t^c_i~t^a_k~t^d_l~\langle kl\Vert cd \rangle$$|
# | | | | |
# |$S_7$|$$T_3(-2)$$|$$++--~~~~~+++---$$|$$\frac{1}{4}~t^{aef}_{imn}~\langle mn\Vert ef \rangle$$|

# %% [markdown]
# __coupled-cluster doubles__
#
# |diagram    |   term          |   contractions         | interpretation |
# |:----------| :---------------:|:----------------------:|:--------------:|
# |$D_1$   | $$T_0(+2)$$ |$$0~~~~~0$$|$$\langle ab\Vert ij \rangle$$|
# |$D_{2a}$| $$T_2(0)$$  |$$+~~~~~++--$$| $$\hat{P}(ab)\big\{ t^{ac}_{ij}~f_{bc} \big \}$$|
# |$D_{2b}$| $$T_2(0)$$  |$$-~~~~~++--$$| $$-\hat{P}(ij)\big\{ t^{ab}_{ik}~f_{kj} \big \}$$|
# |$D_{2c}$| $$T_2(0)$$  |$$++~~~~~++--$$| $$\frac{1}{2}~t^{cd}_{ij}~\langle ab\Vert cd \rangle$$|
# |$D_{2d}$| $$T_2(0)$$  |$$--~~~~~++--$$| $$\frac{1}{2}~t^{ab}_{kl}~\langle kl\Vert ij \rangle$$|
# |$D_{2e}$| $$T_2(0)$$  |$$+-~~~~~++--$$| $$\hat{P}(ij) \hat{P}(ab) \big \{~t^{ac}_{ik}~\langle kb\Vert cj \rangle \big \}$$|
# |$D_{3a}$| $$T_2^2(-2)$$|$$++\vert --~~~~~++--\vert ++--$$|$$\frac{1}{4}~t^{cd}_{ij}~t^{ab}_{kl}~\langle kl\Vert cd \rangle$$|
# |$D_{3b}$| $$T_2^2(-2)$$|$$+-\vert +-~~~~~++--\vert ++--$$|$$\hat{P}(ij) \big \{t^{ac}_{ik}~t^{bd}_{jl}~\langle kl\Vert cd \rangle \big \}$$|
# |$D_{3c}$| $$T_2^2(-2)$$|$$++-\vert -~~~~~++--\vert ++--$$|$$-\frac{1}{2}\hat{P}(ij) \big \{t^{dc}_{ik}~t^{ab}_{lj}~\langle kl\Vert cd \rangle \big \}$$|
# |$D_{3d}$| $$T_2^2(-2)$$|$$+--\vert +~~~~~++--\vert ++--$$|$$-\frac{1}{2}\hat{P}(ab) \big \{t^{ac}_{lk}~t^{db}_{ij}~\langle kl\Vert cd \rangle \big \}$$|
# |$D_{4a}$|$$T_1(+1)$$|$$+~~~~~+-$$|$$\hat{P}(ij) \big \{t^c_i~\langle ab\Vert cj \rangle \big \}$$|
# |$D_{4b}$|$$T_1(+1)$$|$$-~~~~~+-$$|$$-\hat{P}(ab) \big \{t^a_k~\langle kb\Vert ij \rangle \big \}$$|
# |$D_{5a}$|$$T_1 T_2(-1)$$|$$+\vert -~~~~~+-\vert ++--$$|$$-\hat{P}(ij) \big \{t^c_i~t^{ab}_{kj}~f_{kc} \big \}$$|
# |$D_{5b}$|$$T_1 T_2(-1)$$|$$-\vert +~~~~~+-\vert ++--$$|$$-\hat{P}(ab) \big \{t^a_k~t^{cb}_{ij}~f_{kc} \big \}$$|
# |$D_{5c}$|$$T_1 T_2(-1)$$|$$+\vert +-~~~~~+-\vert ++--$$|$$\hat{P}(ij) \hat{P}(ab) \big \{t^c_i~t^{db}_{kj}~\langle ak\Vert cd \rangle \big \}$$|
# |$D_{5e}$|$$T_1 T_2(-1)$$|$$-\vert ++~~~~~+-\vert ++--$$|$$-\frac{1}{2}\hat{P}(ab) \big \{t^a_k~t^{cd}_{ij}~\langle kb\Vert cd \rangle \big \}$$|
# |$D_{5g}$|$$T_1 T_2(-1)$$|$$+-\vert +~~~~~+-\vert ++--$$|$$\hat{P}(ab) \big \{t^c_k~t^{db}_{ij}~\langle ka\Vert cd \rangle \big \}$$|
# |$D_{5d}$|$$T_1 T_2(-1)$$|$$-\vert +-~~~~~+-\vert ++--$$|$$-\hat{P}(ij) \hat{P}(ab) \big \{t^a_k~t^{cb}_{lj}~\langle kl\Vert ic \rangle \big \}$$|
# |$D_{5f}$|$$T_1 T_2(-1)$$|$$+\vert --~~~~~+-\vert ++--$$|$$\frac{1}{2}\hat{P}(ij) \big \{t^c_i~t^{ab}_{kl}~\langle kl\Vert cj\rangle \big \}$$|
# |$D_{5h}$|$$T_1 T_2(-1)$$|$$+-\vert -~~~~~+-\vert ++--$$|$$-\hat{P}(ij) \big \{t^c_k~t^{ab}_{lj}~\langle kl\Vert ci \rangle \big \}$$|
# |$D_{6a}$|$$T_1^2(0)$$|$$+\vert +~~~~~+-\vert +-$$|$$\frac{1}{2}\hat{P}(ij) \big \{t^c_i~t^d_j~\langle ab\Vert cd \rangle \big \}$$|
# |$D_{6b}$|$$T_1^2(0)$$|$$-\vert -~~~~~+-\vert +-$$|$$\frac{1}{2}\hat{P}(ab) \big \{t^a_k~t^b_l~\langle kl\Vert ij \rangle \big \}$$|
# |$D_{6c}$|$$T_1^2(0)$$|$$+\vert -~~~~~+-\vert +-$$|$$-\hat{P}(ij) \hat{P}(ab) \big \{t^c_i~t^a_k~\langle kb\Vert cj \rangle \big \}$$|
# |$D_{7a}$|$$T_1^2 T_2(-2)$$|$$+\vert +\vert --~~~~~+-\vert +-\vert ++--$$|$$\frac{1}{4}\hat{P}(ij) \big \{t^c_i~t^d_j~t^{ab}_{kl}~\langle kl\Vert cd \rangle \big \}$$|
# |$D_{7b}$|$$T_1^2 T_2(-2)$$|$$-\vert -\vert ++~~~~~+-\vert +-\vert ++--$$|$$\frac{1}{4}\hat{P}(ab) \big \{t^a_k~t^b_l~t^{cd}_{ij}~\langle kl\Vert cd \rangle \big \}$$|
# |$D_{7c}$|$$T_1^2 T_2(-2)$$|$$+\vert -\vert +-~~~~~+-\vert +-\vert ++--$$|$$-\hat{P}(ij) \hat{P}(ab) \big \{t^c_i~t^a_k~t^{db}_{lj}~\langle kl\Vert cd \rangle \big \}$$|
# |$D_{7d}$|$$T_1^2 T_2(-2)$$|$$+-\vert +\vert -~~~~~+-\vert +-\vert ++--$$|$$-\hat{P}(ij) \big \{t^c_k~t^d_i~t^{ab}_{lj}~\langle kl\Vert cd \rangle \big \}$$|
# |$D_{7e}$|$$T_1^2 T_2(-2)$$|$$+-\vert -\vert +~~~~~+-\vert +-\vert ++--$$|$$-\hat{P}(ab) \big \{t^c_k~t^a_l~t^{db}_{ij}~\langle kl\Vert cd \rangle \big \}$$|
# |$D_{8a}$|$$T_1^3(-1)$$|$$+\vert -\vert +~~~~~+-\vert +-\vert +-$$|$$\frac{1}{2}\hat{P}(ij) \hat{P}(ab) \big \{t^c_i~t^a_k~t^d_j~\langle kb\Vert cd \rangle \big \}$$*|
# |$D_{8b}$|$$T_1^3(-1)$$|$$+\vert -\vert -~~~~~+-\vert +-\vert +-$$|$$\frac{1}{2}\hat{P}(ij) \hat{P}(ab) \big \{t^c_i~t^a_k~t^b_l~\langle kl\Vert cj \rangle \big \}$$|
# |$D_{9}$|$$T_1^4(-2)$$|$$+\vert +\vert -\vert +~~~~~+-\vert +-\vert +-\vert +-$$|$$\frac{1}{4}\hat{P}(ij) \hat{P}(ab) \big \{t^c_i~t^d_j~t^a_k~t^b_l \langle kb\Vert cd \rangle \big \}$$|
# | | | | |
# |$D_{10a}$|$$T_3(-1)$$|$$+-~~~~~+++---$$|$$t^{abe}_{ijm} f_{me}$$|
# |$D_{10b}$|$$T_3(-1)$$|$$++-~~~~~+++---$$|$$\frac{1}{2}\hat{P}(ab) \big \{t^{aef}_{ijm}~\langle bm\Vert ef \rangle \big \}$$|
# |$D_{10c}$|$$T_3(-1)$$|$$+--~~~~~+++---$$|$$-\frac{1}{2}\hat{P}(ij) \big \{t^{abe}_{imn}~\langle mn\Vert je \rangle \big \}$$|
# |$D_{11a}$|$$T_1 T_3(-2)$$|$$+-\vert +-~~~~~+-\vert +++---$$|$$t^e_m~t^{fab}_{nij} ~\langle mn\Vert ef \rangle$$|
# |$D_{11b}$|$$T_1 T_3(-2)$$|$$-\vert ++-~~~~~+-\vert +++---$$|$$-\hat{P}(ab) \big \{t^a_m~t^{efb}_{ijn} ~\langle mn\Vert ef \rangle \big \}$$**|
# |$D_{11c}$|$$T_1 T_3(-2)$$|$$+\vert --+~~~~~+-\vert +++---$$|$$-\hat{P}(ij) \big \{t^e_i~t^{afb}_{mnj} ~\langle mn\Vert ef \rangle \big \}$$**|
# |$D_{12}$|$$T_4(-2)$$|$$++--~~~~~++++----$$|$$\frac{1}{4} t^{abef}_{ijmn} \langle mn\Vert ef \rangle$$|
#
# __\*__ $D_{8a}$ has the same sign as $D_{8b}$ but both have the same number of loops and differ by one hole line so cannot be of the same sign. $D_{8a}$ should be -ve.
#
# __\*\*__ $D_{11b}$ and $D_{11c}$ both have equivalent lines and so should have factor $\frac{1}{2}$ this is confirmed by cogus.

# %% [markdown]
# __coupled-cluster triples__
#
# |diagram    |   term          |   contractions         | interpretation |
# |:----------|:---------------:|:----------------------:|:--------------:|
# |$T_{1a}$|$$T_2(+1)$$|$$+~~~~~++--$$|$$\hat{P}(k/ij)~\hat{P}(a/bc) \big \{ t^{ad}_{ij}~\langle bc\Vert dk \rangle \big \}$$|
# |$T_{1b}$|$$T_2(+1)$$|$$-~~~~~++--$$|$$-\hat{P}(i/jk)~\hat{P}(c/ab) \big \{ t^{ab}_{il}~\langle lc\Vert jk \rangle \big \}$$|
# |$T_{2a}$ |$$T_3(0)$$|$$+~~~~~+++---$$ |$$\hat{P}(c/ab)\big \{ t^{abd}_{ijk}~ f_{cd}\big \} $$|
# |$T_{2b}$ |$$T_3(0)$$|$$-~~~~+++---$$|$$-\hat{P}(k/ij) \big \{ t^{abc}_{ijl}~ f_{lk} \big \}$$|
# |$T_{2c}$|$$T_3(0)$$|$$++~~~~~+++---$$|$$\frac{1}{2} \hat{P}(c/ab)~ \big \{ t^{dec}_{ijk}~\langle ab\Vert de \rangle \big \}$$|
# |$T_{2d}$|$$T_3(0)$$|$$--~~~~~+++---$$|$$\frac{1}{2}~\hat{P}(k/ij) \big \{ t^{abc}_{lmk} \langle lm\Vert ij \rangle \big \}$$|
# |$T_{2e}$|$$T_3(0)$$|$$+-~~~~~+++---$$|$$\hat{P}(i/jk)~\hat{P}(a/bc)\big \{ t^{dbc}_{ljk} \langle al\Vert id \rangle \big \}$$|
# |$T_{3a}$ |$$T_2 T_2(-1)$$|$$+\vert -~~~~~++--\vert ++--$$|$$-\hat{P}(k/ij) \hat{P}(a/bc) \big \{ t^{ad}_{ij}~t^{bc}_{lk}~f_{ld} \big \}$$|
# |$T_{3b}$|$$T_2 T_2(-1)$$|$$+-\vert +~~~~~++--\vert ++--$$|$$\hat{P}(i/jk)~\hat{P}(abc) \big \{ t^{ad}_{il}~t^{ec}_{jk} \langle lb\Vert de \rangle \big \}$$|
# |$T_{3c}$|$$T_2 T_2(-1)$$|$$+-\vert -~~~~~++--\vert ++--$$|$$-\hat{P}(ijk)\hat{P}(a/bc) \big \{ t^{ad}_{il}~ t^{bc}_{mk}~\langle lm\Vert dj \rangle \big \}$$|
# |$T_{3d}$|$$T_2 T_2(-1)$$|$$-\vert ++~~~~~++--\vert ++--$$|$$-\frac{1}{2}~\hat{P}(i/jk)~\hat{P}(c/ab) \big \{ t^{ab}_{il}~t^{de}_{jk} \langle lc\Vert de \rangle \big \}$$|
# |$T_{3e}$|$$T_2 T_2(-1)$$|$$+\vert --~~~~~++--\vert ++--$$|$$\frac{1}{2}~\hat{P}(k/ij)~\hat{P}(a/bc) \big \{ t^{ad}_{ij}~t^{bc}_{lm} \langle lm\Vert dk \rangle \big \}$$|
# |$T_{4a}$|$$T_1 T_2(0)$$|$$+\vert +~~~~~+-\vert ++--$$|$$\hat{P}(i/jk)~\hat{P}(c/ab)\big \{ t^d_i~ t^{ec}_{jk} \langle ab\Vert de \rangle \big \}$$|
# |$T_{4b}$|$$T_1 T_2(0)$$|$$+\vert +~~~~~+-\vert ++--$$|$$\hat{P}(k/ij)~\hat{P}(a/bc)\big \{ t^a_l~ t^{bc}_{mk} \langle lm\Vert ij \rangle \big\}$$|
# |$T_{4c}$|$$T_1 T_2(0)$$|$$+\vert -~~~~~+-\vert ++--$$|$$-\hat{P}(ijk)~\hat{P}(a/bc)\big \{ t^d_j~ t^{bc}_{lk} \langle al\Vert id \rangle \big\}$$|
# |$T_{4d}$|$$T_1 T_2(0)$$|$$-\vert +~~~~~+-\vert ++--$$|$$-\hat{P}(i/jk)~\hat{P}(abc)\big \{ t^b_l~t^{dc}_{jk} \langle al\Vert id \rangle \big \}$$
# |$T_{5a}$|$$T_2 T_3(-2)$$|$$+-\vert +-~~~~~++--\vert +++---$$|$$\hat{P}(i/jk) \hat{P}(a/bc) \big \{ t^{ad}_{il}~t^{ebc}_{mjk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{5b}$|$$T_2 T_3(-2)$$|$$++-\vert -~~~~~++--\vert +++---$$|$$-\frac{1}{2}\hat{P}(i/jk) \big \{ t^{de}_{li}~t^{abc}_{mjk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{5c}$|$$T_2 T_3(-2)$$|$$+--\vert +~~~~~++--\vert +++---$$|$$-\frac{1}{2}\hat{P}(a/bc) \big \{ t^{da}_{lm}~t^{ebc}_{ijk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{5d}$|$$T_2 T_3(-2)$$|$$+\vert +--~~~~~++--\vert +++---$$|$$-\frac{1}{2}\hat{P}(k/ij) \hat{P}(a/bc) \big \{ t^{ad}_{ij}~t^{bec}_{lmk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{5e}$|$$T_2 T_3(-2)$$|$$-\vert ++-~~~~~++--\vert +++---$$|$$-\frac{1}{2}\hat{P}(i/jk) \hat{P}(c/ab) \big \{ t^{ab}_{il}~t^{dec}_{jmk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{5f}$|$$T_2 T_3(-2)$$|$$++\vert --~~~~~++--\vert +++---$$|$$\frac{1}{4}\hat{P}(k/ij) \big \{ t^{de}_{ij}~t^{abc}_{lmk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{5g}$|$$T_2 T_3(-2)$$|$$--\vert ++~~~~~++--\vert +++---$$|$$\frac{1}{4}\hat{P}(c/ab) \big \{ t^{ab}_{lm}~t^{dec}_{ijk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{6a}$|$$T_1 T_3(-1)$$|$$+\vert -~~~~~+++---$$|$$-\hat{P}(i/jk) \big \{ t^d_i t^{abc}_{ljk} f_{ld} \big \}$$|
# |$T_{6b}$|$$T_1 T_3(-1)$$|$$-\vert +~~~~~+++---$$|$$-\hat{P}(a/bc) \big \{ t^a_l t^{dbc}_{ijk} f_{ld} \big \}$$|
# |$T_{6c}$|$$T_1 T_3(-1)$$|$$+\vert +-~~~~~+-\vert +++---$$|$$\hat{P}(i/jk)~\hat{P}(a/bc) \big \{ t^{d}_{i}~t^{ebc}_{ljk} \langle al\Vert de \rangle \big \}$$|
# |$T_{6d}$|$$T_1 T_3(-1)$$|$$-\vert +-~~~~~+-\vert +++---$$|$$-\hat{P}(i/jk)~\hat{P}(a/bc) \big \{ t^{a}_{l}~t^{dbc}_{mjk} \langle lm\Vert id \rangle \big \}$$|
# |$T_{6e}$|$$T_1 T_3(-1)$$|$$+-\vert +~~~~~+-\vert +++---$$|$$\hat{P}(a/bc) \big \{ t^{d}_{l}~t^{ebc}_{ijk} \langle la\Vert de \rangle \big \}$$|
# |$T_{6f}$|$$T_1 T_3(-1)$$|$$+-\vert -~~~~~+-\vert +++---$$|$$-\hat{P}(i/jk) \big \{ t^{d}_{l}~t^{abc}_{mjk} \langle lm\Vert di \rangle \big \}$$|
# |$T_{6g}$|$$T_1 T_3(-1)$$|$$-\vert ++~~~~~+-\vert +++---$$|$$-\frac{1}{2}\hat{P}(abc) \big \{ t^{a}_{l}~t^{dec}_{ijk} \langle lb\Vert de \rangle \big \}$$|
# |$T_{6h}$|$$T_1 T_3(-1)$$|$$+\vert --~~~~~+-\vert +++---$$|$$\frac{1}{2}\hat{P}(ijk) \big \{ t^{d}_{i}~t^{abc}_{lmk} \langle lm\Vert dj \rangle \big \}$$|
# |$T_{7a}$|$$T_1 T_1 T_2(-1)$$|$$+\vert -\vert +~~~~~+-\vert +-\vert ++--$$|$$-\hat{P}(i/jk)~\hat{P}(abc) \big \{ t^{d}_{i}~t^a_l~t^{ec}_{jk} \langle lb\Vert de \rangle \big \}$$|
# |$T_{7b}$|$$T_1 T_1 T_2(-1)$$|$$+\vert -\vert -~~~~~+-\vert +-\vert ++--$$|$$\hat{P}(ijk)~\hat{P}(a/bc) \big \{ t^{d}_{i}~t^a_l~t^{bc}_{mk} \langle lm\Vert dj \rangle \big \}$$|
# |$T_{7c}$|$$T_1 T_1 T_2(-1)$$|$$+\vert +\vert -~~~~~+-\vert +-\vert ++--$$|$$-\hat{P}(k/ij)~\hat{P}(a/bc) \big \{ t^{d}_{i}~t^e_j~t^{bc}_{lk} \langle al\Vert de \rangle \big \}$$|
# |$T_{7d}$|$$T_1 T_1 T_2(-1)$$|$$-\vert -\vert +~~~~~+-\vert +-\vert ++--$$|$$\hat{P}(i/jk)~\hat{P}(c/ab) \big \{ t^{a}_{l}~t^b_m~t^{dc}_{jk} \langle lm\Vert id \rangle \big \}$$|
# |$T_{8a}$|$$T_1 T_2^2(-2)$$|$$+-\vert +\vert -~~~~~+-\vert ++--\vert ++--$$|$$-\hat{P}(i/jk)\hat{P}(c/ab) \big \{t^d_l~t^{ab}_{im}~t^{ec}_{jk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{8b}$|$$T_1 T_2^2(-2)$$|$$+\vert +-\vert -~~~~~+-\vert ++--\vert ++--$$|$$-\hat{P}(ijk)\hat{P}(a/bc) \big \{t^e_j~t^{ad}_{il}~t^{bc}_{mk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{8c}$|$$T_1 T_2^2(-2)$$|$$-\vert +-\vert +~~~~~+-\vert ++--\vert ++--$$|$$-\hat{P}(i/jk)\hat{P}(abc) \big \{t^b_m~t^{ad}_{il}~t^{ec}_{jk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{8d}$|$$T_1 T_2^2(-2)$$|$$+\vert --\vert +~~~~~+-\vert ++--\vert ++--$$|$$\frac{1}{2}\hat{P}(i/jk)\hat{P}(c/ab) \big \{t^d_i~t^{ab}_{lm}~t^{ec}_{jk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{8e}$|$$T_1 T_2^2(-2)$$|$$-\vert ++\vert -~~~~~+-\vert ++--\vert ++--$$|$$\frac{1}{2}\hat{P}(k/ij)\hat{P}(a/bc) \big \{t^a_l~t^{de}_{ij}~t^{bc}_{mk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{9a}$|$$T_1 T_1 T_3(-2)$$|$$+-\vert +\vert -~~~~~+-\vert +-\vert +++---$$|$$-\hat{P}(i/jk) \big \{t^d_l~t^e_i~t^{abc}_{mjk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{9b}$|$$T_1 T_1 T_3(-2)$$|$$+-\vert -\vert +~~~~~+-\vert +-\vert +++---$$|$$-\hat{P}(a/bc) \big \{t^d_l~t^a_m~t^{ebc}_{ijk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{9c}$|$$T_1 T_1 T_3(-2)$$|$$+\vert --\vert +~~~~~+-\vert +-\vert +++---$$|$$\frac{1}{2}\hat{P}(j/ik) \big \{t^d_i~t^e_k~t^{abc}_{ljm}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{9d}$|$$T_1 T_1 T_3(-2)$$|$$-\vert -\vert ++~~~~~+-\vert +-\vert +++---$$|$$\frac{1}{2} \hat{P}(b/ac) \big \{t^a_l~t^c_m~t^{dbe}_{ijk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{9e}$|$$T_1 T_1 T_3(-2)$$|$$+\vert -\vert +-~~~~~+-\vert +-\vert +++---$$|$$-\hat{P}(i/jk) \hat{P}(a/bc) \big \{t^d_i~t^a_l~t^{ebc}_{mjk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{10a}$|$$T_1^3 T_2(-2)$$|$$+\vert -\vert +\vert -~~~~~+-\vert +-\vert +-\vert ++--$$|$$\hat{P}(k/ij) \hat{P}(a/bc) \big \{t^d_i~t^a_l~t^e_j~t^{bc}_{mk}~\langle lm\Vert de \rangle \big \}$$|
# |$T_{10b}$|$$T_1^3 T_2(-2)$$|$$+\vert -\vert -\vert +~~~~~+-\vert +-\vert +-\vert ++--$$|$$\hat{P}(i/jk) \hat{P}(c/ab) \big \{t^d_i~t^a_l~t^b_m~t^{ec}_{jk}~\langle lm\Vert de \rangle \big \}$$|
# | | | | |
# |$T_{11a}$|$$T_4(-1)$$|$$+-~~~~~++++----$$|$$t^{abce}_{ijkm}~f_{me}$$|
# |$T_{11b}$|$$T_4(-1)$$|$$++-~~~~~++++----$$|$$\frac{1}{2} \hat{P}(c/ab) \big \{t^{abef}_{ijkm}~\langle cm\Vert ef \rangle \big \}$$|
# |$T_{11c}$|$$T_4(-1)$$|$$+--~~~~~++++----$$|$$-\frac{1}{2} \hat{P}(k/ij) \big \{t^{abcf}_{ijmn}~\langle mn\Vert kf \rangle \big \}$$|
# |$T_{12a}$|$$T_1 T_4(-2)$$|$$+-\vert +-~~~~~+-\vert ++++----$$|$$t^e_m~t^{fabc}_{nijk}~\langle mn\Vert ef \rangle$$|
# |$T_{12b}$|$$T_1 T_4(-2)$$|$$-\vert ++-~~~~~+-\vert ++++----$$|$$-\frac{1}{2} \hat{P}(i/jk) \big \{t^e_i~t^{afbc}_{mnjk}~\langle mn\Vert ef \rangle \big \}$$|
# |$T_{12c}$|$$T_1 T_4(-2)$$|$$+\vert +--~~~~~+-\vert ++++----$$|$$-\frac{1}{2} \hat{P}(a/bc) \big \{t^a_m~t^{efbc}_{injk}~\langle mn\Vert ef \rangle \big \}$$|

# %% [markdown]
# __coupled-cluster quadruples__
#
# |diagram    |   term          |   contractions         | interpretation |
# |:----------|:---------------:|:----------------------:|:--------------:|
# |$Q_{1a}$|$$T_3(+1)$$|$$+~~~~~+++---$$|$$\hat{P}(ijk/l) \hat{P}(ab/cd) \big \{~ t^{abe}_{ijk} ~\langle cd\Vert el \rangle \big \}$$|
# |$Q_{1b}$|$$T_3(+1)$$|$$-~~~~~+++---$$|$$-\hat{P}(ij/kl) \hat{P}(abc/d)~ \big \{t^{abc}_{ijm}~ \langle md\Vert kl \rangle  \big \}$$|
# |$Q_{2a}$|$$T_4(0)$$|$$+~~~~~++++----$$|$$ \hat{P}(d/abc)\big \{~ t^{abce}_{ijkl}~ f_{de}  \big \}$$|
# |$Q_{2b}$|$$T_4(0)$$|$$-~~~~~++++----$$|$$ -\hat{P}(l/ijk)\big \{~ t^{abcd}_{ijkm}~ f_{ml}  \big \}$$|
# |$Q_{2c}$|$$T_4(0)$$|$$++~~~~~++++----$$|$$ \frac{1}{2}~\hat{P}(ab/cd) \big \{ t^{efcd}_{ijkl} \langle ab\Vert ef \rangle \big \}$$|
# |$Q_{2d}$|$$T_4(0)$$|$$--~~~~~++++----$$|$$ \frac{1}{2}~\hat{P}(ij/kl) \big \{ t^{abcd}_{mnkl} \langle ij\Vert mn \rangle \big \}$$|
# |$Q_{2e}$|$$T_4(0)$$|$$+-~~~~~++++----$$|$$ -\hat{P}(j/ikl)\hat{P}(a/bcd) \big \{ t^{ebcd}_{imkl} \langle am\Vert ej  \rangle \big \}$$|
# |$Q_{3a}$|$$T_1 T_3(0)$$|$$+\vert +~~~~~+-\vert +++---$$|$$ \hat{P}(i/jkl) \hat{P}(ab/cd)  \big \{~t^e_i~ t^{fcd}_{jkl} ~\langle ab\Vert ef \rangle \big \}$$|
# |$Q_{3b}$|$$T_1 T_3(0)$$|$$-\vert -~~~~~+-\vert +++---$$|$$ \hat{P}(ij/kl) \hat{P}(a/bcd)\big \{~t^a_m~ t^{bcd}_{nkl} ~\langle mn\Vert ij \rangle \big \}$$|
# |$Q_{3c}$|$$T_1 T_3(0)$$|$$+\vert -~~~~~+-\vert +++---$$|$$ -\hat{P}(i/j/kl) \hat{P}(a/bcd) \big \{~t^e_j~ t^{bcd}_{mkl} ~\langle am\Vert ie \rangle \big \}$$|
# |$Q_{3d}$|$$T_1 T_3(0)$$|$$-\vert +~~~~~+-\vert +++---$$|$$ -\hat{P}(i/jkl) \hat{P}(a/b/cd)\big \{~t^b_m~ t^{ecd}_{jkl} ~\langle am\Vert ie \rangle \big \}$$|
# |$Q_{4a}$|$$T_1 T_4(-1)$$|$$+\vert -~~~~~+-\vert ++++----$$|$$ -\hat{P}(i/jkl) \big \{t^e_i t^{abcd}_{mjkl}~f_{me} \big \}$$|
# |$Q_{4b}$|$$T_1 T_4(-1)$$|$$-\vert +~~~~~+-\vert ++++----$$|$$ -\hat{P}(a/bcd) \big \{t^a_m t^{ebcd}_{ijkl}~f_{me} \big \}$$|
# |$Q_{4c}$|$$T_1 T_4(-1)$$|$$+-\vert +~~~~~+-\vert ++++----$$|$$ \hat{P}(a/bcd) \big \{t^e_m t^{fbcd}_{ijkl}~\langle ma\Vert ef \rangle \big \}$$|
# |$Q_{4d}$|$$T_1 T_4(-1)$$|$$+-\vert -~~~~~+-\vert ++++----$$|$$ -\hat{P}(i/jkl) \big \{t^e_m t^{abcd}_{njkl}~\langle mn\Vert ei \rangle \big \}$$|
# |$Q_{4e}$|$$T_1 T_4(-1)$$|$$+\vert --~~~~~+-\vert ++++----$$|$$ \frac{1}{2}~\hat{P}(i/j/kl)~ \big \{t^e_i t^{abcd}_{mnkl}~\langle mn\Vert ej \rangle \big \}$$|
# |$Q_{4f}$|$$T_1 T_4(-1)$$|$$-\vert ++~~~~~+-\vert ++++----$$|$$ -\frac{1}{2}~\hat{P}(a/b/cd)~ \big \{t^a_m t^{efcd}_{ijkl}~\langle mb\Vert ef \rangle \big \}$$|
# |$Q_{4g}$|$$T_1 T_4(-1)$$|$$+\vert +-~~~~~+-\vert ++++----$$|$$ \hat{P}(i/jkl) \hat{P}(a/bcd)~ \big \{t^e_i t^{fbcd}_{mjkl}~\langle am\Vert ef \rangle \big \}$$|
# |$Q_{4h}$|$$T_1 T_4(-1)$$|$$-\vert +-~~~~~+-\vert ++++----$$|$$ -\hat{P}(i/jkl) \hat{P}(a/bcd)~ \big \{t^a_m t^{ebcd}_{njkl}~\langle mn\Vert ie \rangle \big \}$$|
# |$Q_{5a}$|$$T_2 T_2(0)$$|$$+\vert +~~~~~++--\vert ++--$$|$$\frac{1}{2} \hat{P}(ij/kl) \hat{P}(a/bc/d) \big \{t^{ae}_{ij}~t^{fd}_{kl}~\langle bc\Vert ef \rangle \big \}$$|
# |$Q_{5b}$|$$T_2 T_2(0)$$|$$-\vert -~~~~~++--\vert ++--$$|$$\frac{1}{2} \hat{P}(i/jk/l) \hat{P}(ab/cd) \big \{ t^{ab}_{im} ~t^{cd}_{nl}~ \langle mn\Vert jk \rangle \big \}$$|
# |$Q_{5c}$|$$T_2 T_2(0)$$|$$+\vert -~~~~~++--\vert ++--$$|$$-\hat{P}(ij/k/l) \hat{P}(a/bd/c) \big \{ t^{ae}_{ij} ~t^{bd}_{ml}~\langle mc\Vert ek \rangle \big \}$$|
# |$Q_{6a}$|$$T_2 T_3(-1)$$|$$+\vert -~~~~~++--\vert +++---$$|$$-\hat{P}(ij/kl)\hat{P}(a/bcd) \big \{t^{ae}_{ij}~t^{bcd}_{mkl}~f_{me} \big \}$$|
# |$Q_{6b}$|$$T_2 T_3(-1)$$|$$-\vert +~~~~~++--\vert +++---$$|$$-\hat{P}(i/jkl)\hat{P}(ab/cd) \big \{t^{ab}_{im}~t^{ecd}_{jkl}~f_{me} \big \}$$|
# |$Q_{6c}$|$$T_2 T_3(-1)$$|$$+\vert --~~~~~++--\vert +++---$$|$$\frac{1}{2}\hat{P}(ij/k/l)\hat{P}(a/bcd) \big \{t^{ae}_{ij}~t^{bcd}_{mnl}~\langle mn\Vert ek \rangle \big \}$$|
# |$Q_{6d}$|$$T_2 T_3(-1)$$|$$-\vert ++~~~~~++--\vert +++---$$|$$-\frac{1}{2} \hat{P}(i/jkl) \hat{P}(ab/c/d) \big \{t^{ab}_{im}~t^{efd}_{jkl}~ \langle mc\Vert ef \rangle \big \}$$|
# |$Q_{6e}$|$$T_2 T_3(-1)$$|$$+\vert +-~~~~~++--\vert +++---$$|$$ \hat{P}(ij/kl) \hat{P}(a/b/cd) \big \{ t^{ae}_{ij}~ t^{fcd}_{mkl}~ \langle bm\Vert ef \rangle \big \}$$|
# |$Q_{6f}$|$$T_2 T_3(-1)$$|$$-\vert +-~~~~~++--\vert +++---$$|$$ -\hat{P}(i/j/kl) \hat{P}(ab/cd) \big \{ t^{ab}_{im}~ t^{ecd}_{nkl}~ \langle mn\Vert je \rangle \big \}$$|
# |$Q_{6g}$|$$T_2 T_3(-1)$$|$$++\vert -~~~~~++--\vert +++---$$|$$- \frac{1}{2} \hat{P}(ij/kl) \hat{P}(a/bcd) \big \{ t^{ef}_{ij}~ t^{bcd}_{mkl}~ \langle am\Vert ef \rangle \big \}$$|
# |$Q_{6h}$|$$T_2 T_3(-1)$$|$$+-\vert +~~~~~++--\vert +++---$$|$$\hat{P}(i/jkl) \hat{P}(a/b/cd) \big \{ t^{ae}_{im}~ t^{fcd}_{jkl}~ \langle mb\Vert ef \rangle \big \}$$|
# |$Q_{6i}$|$$T_2 T_3(-1)$$|$$+-\vert -~~~~~++--\vert +++---$$|$$- \frac{1}{2} \hat{P}(i/j/kl) \hat{P}(a/bcd) \big \{ t^{ae}_{im}~ t^{bcd}_{nkl}~ \langle mn\Vert ej \rangle \big \}$$|
# |$Q_{6j}$|$$T_2 T_3(-1)$$|$$+\vert --~~~~~++--\vert +++---$$|$$\frac{1}{2} \hat{P}(i/jkl) \hat{P}(ab/cd) \big \{ t^{ab}_{mn}~ t^{ecd}_{jkl}~ \langle mn\Vert ie \rangle \big \}$$|
# |$Q_{7a}$|$$T_2 T_4(-2)$$|$$++-\vert -~~~~~++--\vert ++++----$$|$$-\frac{1}{2} \hat{P}(i/jkl) \big \{t^{ef}_{mi}~t^{abcd}_{njkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{7b}$|$$T_2 T_4(-2)$$|$$+--\vert +~~~~~++--\vert ++++----$$|$$-\frac{1}{2} \hat{P}(a/bcd) \big \{t^{ea}_{mn}~t^{fbcd}_{ijkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{7c}$|$$T_2 T_4(-2)$$|$$++\vert --~~~~~++--\vert ++++----$$|$$\frac{1}{4} \hat{P}(ij/kl) \big \{t^{ef}_{ij}~t^{abcd}_{mnkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{7d}$|$$T_2 T_4(-2)$$|$$--\vert ++~~~~~++--\vert ++++----$$|$$\frac{1}{4} \hat{P}(ab/cd) \big \{t^{ab}_{mn}~t^{efcd}_{ijkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{7e}$|$$T_2 T_4(-2)$$|$$+-\vert +-~~~~~++--\vert ++++----$$|$$ \hat{P}(i/jkl)\hat{P}(a/bcd) \big \{t^{ae}_{im}~t^{fbcd}_{njkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{7f}$|$$T_2 T_4(-2)$$|$$+\vert +--~~~~~++--\vert ++++----$$|$$-\frac{1}{2} \hat{P}(ij/kl)\hat{P}(a/bcd) \big \{t^{ae}_{ij}~t^{bfcd}_{mnkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{7g}$|$$T_2 T_4(-2)$$|$$-\vert ++-~~~~~++--\vert ++++----$$|$$ -\frac{1}{2}\hat{P}(i/jkl)\hat{P}(ab/cd) \big \{t^{ab}_{im}~t^{efcd}_{jnkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{8a}$|$$T_3 T_3(-2)$$|$$+-\vert +-~~~~~+++---\vert +++---$$|$$\frac{1}{2}\hat{P}(ij/kl) \hat{P}(ab/cd) \big \{ t^{abe}_{ijm}~t^{fcd}_{nkl}~\langle mn\Vert ef \big \}$$|
# |$Q_{8b}$|$$T_3 T_3(-2)$$|$$++\vert --~~~~~+++---\vert +++---$$|$$\frac{1}{4} \hat{P}(ijk/l) \hat{P}(a/bcd) \big \{ t^{aef}_{ijk}~t^{bcd}_{mnl}~\langle mn\Vert ef \big \}$$|
# |$Q_{8c}$|$$T_3 T_3(-2)$$|$$++-\vert -~~~~~+++---\vert +++---$$|$$-\frac{1}{2} \hat{P}(ij/kl) \hat{P}(a/bcd) \big \{ t^{aef}_{imj}~t^{bcd}_{nkl}~\langle mn\Vert ef \big \}$$|
# |$Q_{8d}$|$$T_3 T_3(-2)$$|$$+--\vert +~~~~~+++---\vert +++---$$|$$-\frac{1}{2} \hat{P}(i/jkl) \hat{P}(ab/cd) \big \{ t^{aeb}_{imn}~t^{fcd}_{jkl}~\langle mn\Vert ef \big \}$$|
# |$Q_{9a}$|$$T_2^3(-2)$$|$$-\vert ++\vert -~~~~~++--\vert ++--\vert ++--$$|$$\frac{1}{4} \hat{P}(i/jk/l) \hat{P}(ab/cd) \big \{ t^{ab}_{im}~t^{ef}_{jk}~t^{cd}_{nl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{9b}$|$$T_2^3(-2)$$|$$+\vert --\vert +~~~~~++--\vert ++--\vert ++--$$|$$\frac{1}{4} \hat{P}(ij/kl) \hat{P}(a/bc/d) \big \{ t^{ae}_{ij}~t^{bc}_{mn}~t^{fd}_{kl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{9c}$|$$T_2^3(-2)$$|$$+\vert -\vert +-~~~~~++--\vert ++--\vert ++--$$|$$ -\hat{P}(ij/k/l) \hat{P}(a/bc/d) \big \{ t^{ae}_{ij}~t^{bc}_{mk}~t^{fd}_{nl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{10a}$|$$T_1^2 T_3(-1)$$|$$+\vert +\vert -~~~~~+-\vert +-\vert +++---$$|$$-\frac{1}{2}\hat{P}(i/j/kl) \hat{P}(a/bcd) \big \{t^e_i~t^f_j~t^{bcd}_{mkl}~\langle am\Vert ef \rangle \big \}$$|
# |$Q_{10b}$|$$T_1^2 T_3(-1)$$|$$+\vert -\vert +~~~~~+-\vert +-\vert +++---$$|$$-\hat{P}(i/jkl) \hat{P}(a/b/cd) \big \{t^e_i~t^b_m~t^{fcd}_{jkl}~\langle am\Vert ef \rangle \big \}$$|
# |$Q_{10c}$|$$T_1^2 T_3(-1)$$|$$-\vert +\vert -~~~~~+-\vert +-\vert +++---$$|$$ \hat{P}(i/j/kl) \hat{P}(a/bcd) \big \{t^a_m~t^e_j~t^{bcd}_{nkl}~\langle mn\Vert ie \rangle \big \}$$|
# |$Q_{10d}$|$$T_1^2 T_3(-1)$$|$$-\vert -\vert +~~~~~+-\vert +-\vert +++---$$|$$ \frac{1}{2}\hat{P}(i/jkl) \hat{P}(a/b/cd) \big \{t^a_m~t^b_n~t^{ecd}_{jkl}~\langle mn\Vert ie \rangle \big \}$$|
# |$Q_{11a}$|$$T_1^2 T_4(-2)$$|$$+-\vert +\vert -~~~~~+-\vert +-\vert ++++----$$|$$-\hat{P}(i/jkl) \big \{t^e_m~t^f_i~t^{abcd}_{njkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{11b}$|$$T_1^2 T_4(-2)$$|$$+-\vert -\vert +~~~~~+-\vert +-\vert ++++----$$|$$-\hat{P}(a/bcd) \big \{t^e_m~t^a_n~t^{fbcd}_{ijkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{11c}$|$$T_1^2 T_4(-2)$$|$$+\vert +\vert --~~~~~+-\vert +-\vert ++++----$$|$$\frac{1}{4} \hat{P}(i/j/kl) \big \{t^e_i~t^f_j~t^{abcd}_{mnkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{11d}$|$$T_1^2 T_4(-2)$$|$$-\vert -\vert ++~~~~~+-\vert +-\vert ++++----$$|$$\frac{1}{4} \hat{P}(a/b/cd) \big \{t^a_m~t^b_n~t^{efcd}_{ijkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{11e}$|$$T_1^2 T_4(-2)$$|$$+\vert -\vert +-~~~~+-\vert +-\vert ++++----$$|$$-\hat{P}(i/jkl) \hat{P}(a/bcd) \big \{ t^e_i~t^a_m~t^{fbcd}_{njkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{12a}$|$$T_1 T_2^2(-1)$$|$$+\vert -\vert +~~~~~+-\vert ++--\vert ++--$$|$$-\hat{P}(i/j/kl) \hat{P}(ab/c/d) \big \{t^e_i~t^{ab}_{mj}~t^{fd}_{kl}~\langle mc\Vert ef \rangle \big \}$$|
# |$Q_{12b}$|$$T_1 T_2^2(-1)$$|$$+\vert -\vert -~~~~~+-\vert ++--\vert ++--$$|$$\frac{1}{2}\hat{P}(ijkl) \hat{P}(ab/cd) \big \{t^e_i~t^{ab}_{mj}~t^{cd}_{nl}~\langle mn\Vert ek \rangle \big \}$$|
# |$Q_{12c}$|$$T_1 T_2^2(-1)$$|$$-\vert +\vert +~~~~~+-\vert ++--\vert ++--$$|$$- \frac{1}{2} \hat{P}(ij/kl) \hat{P}(abcd) \big \{t^a_m~t^{eb}_{ij}~t^{fd}_{kl}~\langle mc\Vert ef \rangle \big \}$$|
# |$Q_{12d}$|$$T_1 T_2^2(-1)$$|$$-\vert +\vert -~~~~~+-\vert ++--\vert ++--$$|$$- \hat{P}(ij/k/l) \hat{P}(a/b/cd) \big \{t^a_m~t^{eb}_{ij}~t^{cd}_{nl}~\langle mn\Vert ek \rangle \big \}$$|
# |$Q_{13a}$|$$T_1 T_2 T_3(-2)$$|$$+-\vert +\vert -~~~~~+-\vert ++--\vert +++---$$|$$-\hat{P}(ij/kl) \hat{P}(a/bcd) \big \{ t^e_m~t^{af}_{ij}~t^{bcd}_{nkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{13b}$|$$T_1 T_2 T_3(-2)$$|$$+-\vert -\vert +~~~~~+-\vert ++--\vert +++---$$|$$-\hat{P}(i/jkl) \hat{P}(ab/cd) \big \{ t^e_m~t^{ab}_{in}~t^{fcd}_{jkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{13c}$|$$T_1 T_2 T_3(-2)$$|$$+\vert --\vert +~~~~~+-\vert ++--\vert +++---$$|$$\frac{1}{2} \hat{P}(i/jkl) \hat{P}(ab/cd) \big \{ t^e_i~t^{ab}_{mn}~t^{fcd}_{jkl} \langle mn\Vert ef \rangle \big \}$$|
# |$Q_{13d}$|$$T_1 T_2 T_3(-2)$$|$$-\vert ++\vert -~~~~~+-\vert ++--\vert +++---$$|$$\frac{1}{2} \hat{P}(ij/kl) \hat{P}(a/b/cd) \big \{ t^a_m~t^{ef}_{ij}~t^{bcd}_{nkl} \langle mn\Vert ef \rangle \big \}$$|
# |$Q_{13e}$|$$T_1 T_2 T_3(-2)$$|$$+\vert +-\vert -~~~~~+-\vert ++--\vert +++---$$|$$- \hat{P}(i/j/kl) \hat{P}(a/bcd) \big \{ t^f_j~t^{ae}_{im}~t^{bcd}_{nkl} \langle mn\Vert ef \rangle \big \}$$|
# |$Q_{13f}$|$$T_1 T_2 T_3(-2)$$|$$-\vert +-\vert +~~~~~+-\vert ++--\vert +++---$$|$$- \hat{P}(i/jkl) \hat{P}(a/b/cd) \big \{ t^b_n~t^{ae}_{im}~t^{fcd}_{jkl} \langle mn\Vert ef \rangle \big \}$$|
# |$Q_{13g}$|$$T_1 T_2 T_3(-2)$$|$$+\vert +\vert --~~~~~+-\vert ++--\vert +++---$$|$$\frac{1}{2} \hat{P}(i/j/kl) \hat{P}(d/abc) \big \{ t^e_i~t^{abc}_{mjn}~t^{fd}_{kl} \langle mn\Vert ef \rangle \big \}$$|
# |$Q_{13h}$|$$T_1 T_2 T_3(-2)$$|$$-\vert -\vert ++~~~~~+-\vert ++--\vert +++---$$|$$-\frac{1}{2}\hat{P}(ijk/l)\hat{P}(a/b/cd) \big \{ t^a_m~t^{cd}_{nl}~t^{ebf}_{ijk}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{13i}$|$$T_1 T_2 T_3(-2)$$|$$+\vert -\vert +-~~~~~+-\vert ++--\vert +++---$$|$$-\hat{P}(ij/k/l)\hat{P}(ab/cd) \big \{ t^f_k~t^{cd}_{nl}~t^{abe}_{ijm}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{13j}$|$$T_1 T_2 T_3(-2)$$|$$-\vert +\vert +-~~~~~+-\vert ++--\vert +++---$$|$$-\hat{P}(ij/kl)\hat{P}(ab/c/d) \big \{ t^c_n~t^{fd}_{kl}~t^{abe}_{ijm}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{14a}$|$$T_1^3 T_3(-2)$$|$$+\vert -\vert +\vert -~~~~~+-\vert +-\vert +-\vert +++---$$|$$\frac{1}{2} \hat{P}(i/j/kl) \hat{P}(a/bcd) \big \{ t^e_i~t^a_m~t^f_j~t^{bcd}_{nkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{14b}$|$$T_1^3 T_3(-2)$$|$$+\vert -\vert -\vert +~~~~~+-\vert +-\vert +-\vert +++---$$|$$\frac{1}{2} \hat{P}(i/jkl) \hat{P}(a/b/cd) \big \{ t^e_i~t^a_m~t^b_n~t^{fcd}_{jkl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{15a}$|$$T_1^2 T_2^2(-2)$$|$$+\vert +\vert -\vert -~~~~~+-\vert +-\vert ++--\vert ++--$$|$$\frac{1}{4} \hat{P}(i/j/k/l) \hat{P}(ab/cd) \big \{t^e_j~t^f_k~t^{ab}_{im}~t^{cd}_{nl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{15b}$|$$T_1^2 T_2^2(-2)$$|$$-\vert -\vert +\vert +~~~~~+-\vert +-\vert ++--\vert ++--$$|$$\frac{1}{4} \hat{P}(ij/kl) \hat{P}(a/b/c/d) \big \{t^b_m~t^c_n~t^{ae}_{ij}~t^{fd}_{kl}~\langle mn\Vert ef \rangle \big \}$$|
# |$Q_{15c}$|$$T_1^2 T_2^2(-2)$$|$$+\vert -\vert +\vert -~~~~~+-\vert +-\vert ++--\vert ++--$$|$$ \hat{P}(ij/k/l) \hat{P}(a/bc/d) \big \{t^f_l~t^d_n~t^{ae}_{ij}~t^{bc}_{mk}~\langle mn\Vert ef \rangle \big \}$$|
